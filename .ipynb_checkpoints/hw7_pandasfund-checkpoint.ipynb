# %% [markdown]
# # Assignment 7: Pandas Fundementals #

# %% [markdown]
# ## 1. Load data from URL ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "http://www.ldeo.columbia.edu/~danielmw/usgs_earthquakes_2014.csv"

# Load data
df = pd.read_csv(url)

# Display first few rows and info
print(df.head())
print(df.info())
# Out:
#                       time   latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       gap     dmin     rms net          id                   updated  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %% [markdown]
# ## 2. Re-read data so all date columns ID dates and earthquake ID is used as index ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "http://www.ldeo.columbia.edu/~danielmw/usgs_earthquakes_2014.csv"

# Load data
df = pd.read_csv(url)

# Display first few rows and info
print(df.head())
print(df.info())
# Out:
#                       time   latitude  longitude  depth   mag magType  nst  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       gap     dmin     rms net          id                   updated  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %% [markdown]
# ## 3. Use [describe] to get basic stats of all columns ##

# %%
stats = df.describe()
print(stats)

# Identify highest and lowest magnitude
print(f"Max Magnitude: {df['mag'].max()}")
print(f"Min Magnitude: {df['mag'].min()}")
# Out:
#             latitude      longitude          depth            mag  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 nst           gap          dmin            rms
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %% [markdown]
# ## 4. Use [nlargest] to get top 20 earthquakes by magnitude ##

# %%
top_20 = df.nlargest(20, 'mag')
print(top_20[['place', 'mag']])
# Out:
#                                           place  mag
# 37371                 94km NW of Iquique, Chile  8.2
# 50562   19km SE of Little Sitkin Island, Alaska  7.9
# 36918                 53km SW of Iquique, Chile  7.7
# 33808     93km SSE of Kirakira, Solomon Islands  7.6
# 31496      70km SW of Panguna, Papua New Guinea  7.5
# 33537      112km S of Kirakira, Solomon Islands  7.4
# 95913           74km S of Intipuca, El Salvador  7.3
# 31850              33km ESE of Petatlan, Mexico  7.2
# 34318     56km WSW of Panguna, Papua New Guinea  7.1
# 106285      154km NW of Kota Ternate, Indonesia  7.1
# 111052            144km NE of Ndoi Island, Fiji  7.1
# 97602                Southern East Pacific Rise  7.0
# 14025                 272km ESE of Hotan, China  6.9
# 37367                91km WNW of Iquique, Chile  6.9
# 39915          22km SSW of Kamariotissa, Greece  6.9
# 47934             154km NNW of Visokoi Island,   6.9
# 50609     80km SSE of Raoul Island, New Zealand  6.9
# ...

# %% [markdown]
# ## 5. Extract state or country using Pandas text data functions##

# %%
df['country'] = df['place'].str.split(',').str[-1].str.strip()

# %% [markdown]
# ## 6. Display each unique value from new column ##

# %%
print(df['country'].unique())
# Out:
# ['Alaska' 'Nevada' 'Mexico' 'California' 'Papua New Guinea' 'New Zealand'
#  'Missouri' 'South of the Fiji Islands' 'Montana' 'British Virgin Islands'
#  'Washington' 'Oregon' 'Canada' 'Fiji' 'Wyoming' 'Antarctica' 'Chile'
#  'Utah' 'Indonesia' 'Solomon Islands' 'Micronesia' 'Oklahoma' 'Hawaii'
#  'Russia' 'Arizona' 'Philippines' 'Bolivia' 'Greece' 'Japan' 'Puerto Rico'
#  'Iran' 'Tonga' 'Wallis and Futuna' 'Colorado' 'Guam' 'CA'
#  'Carlsberg Ridge' 'Idaho' 'Pakistan'
#  'Off the west coast of northern Sumatra' 'Burma' 'China' 'Peru'
#  'Off the east coast of the North Island of New Zealand' 'Costa Rica'
#  'Reykjanes Ridge' 'East Timor' 'Central East Pacific Rise'
#  'Mid-Indian Ridge' 'Japan region' 'Northern Mariana Islands'
#  'El Salvador' 'Samoa' 'Northern Mid-Atlantic Ridge' 'Taiwan' 'Arkansas'
#  'South Sandwich Islands' 'Colombia' 'Dominican Republic' 'Argentina'
#  'Texas' 'New Hampshire' 'Saint Helena' 'West of Vancouver Island'
# ...

# %% [markdown]
# ## 7. Filter dataset for only earthquakes of magnitude 4 or larger ##

# %%
filtered_df = df[df['mag'] >= 4]

# %% [markdown]
# ## 8. Using the filtered dataset, count the number of earthquakes in each country/state. Make a bar chart of this number for the top 5 locations with the most earthquakes ##

# %%
top_locations = filtered_df['country'].value_counts().head(5)

# Plot
top_locations.plot(kind='bar', color='skyblue')
plt.title('Top 5 Locations for Earthquakes (Mag >= 4)')
plt.xlabel('Location')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## 9. Make histogram of distribution of earthquake magnitudes ##

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Unfiltered 
df['mag'].hist(ax=axes[0], bins=30, log=True, color='gray')
axes[0].set_title('All Earthquakes (Log Scale)')

# Filtered 
filtered_df['mag'].hist(ax=axes[1], bins=30, log=True, color='orange')
axes[1].set_title('Earthquakes Mag >= 4 (Log Scale)')

plt.show()

# %% [markdown]
# ## 10. Visualize the locations of earthquakes by making a scatterplot of their latitude and longitude ##

# %%
# Plot 1: Unfiltered Data
plt.figure(figsize=(10, 6))
plt.scatter(df['longitude'], df['latitude'], c=df['mag'], cmap='viridis', s=1, alpha=0.5)
plt.colorbar(label='Magnitude')
plt.title('Global Earthquake Distribution (Unfiltered)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Plot 2: Filtered Data (Mag >= 4)
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['longitude'], filtered_df['latitude'], 
            c=filtered_df['mag'], cmap='hot', s=10, alpha=0.7)
plt.colorbar(label='Magnitude')
plt.title('Significant Earthquakes (Magnitude >= 4)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# # The filtered map shows the outline of the Ring of Fire, a tectonic plate in the Pacific, home to majority of Earth's volcanoes and earthquakes. These plots show that even though minor earthquakes can happen anywhere, major earthquakes usually occur along tectonic plate lines.
